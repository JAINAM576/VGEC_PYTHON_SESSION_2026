# %%
import time 

start=time.time()

for i in range(100000000):
    pass 


end=time.time()
print(end-start)
# Out:
# 5.038450241088867

# %%
import numpy as np

# %%
start=time.time()

for i in np.zeros(100000000):
    pass 

end=time.time()
print(end-start)
# Out:
# 8.766263961791992

# %%
Vectorization = performing operations on entire arrays at once using optimized low-level code instead of Python loops.

# %% [markdown]
# ┌───────────────────────────────┐
# │        Your Python Code       │
# │                               │
# │   a = np.array([1,2,3,4])     │
# │   b = a * 2                   │
# └───────────────▲───────────────┘
#                 │ Python API Call
#                 ▼
# ┌───────────────────────────────┐
# │        NumPy Python Layer     │  ← thin wrapper
# │   (written in Python/Cython)  │
# └───────────────▲───────────────┘
#                 │ Calls C functions
#                 ▼
# ┌───────────────────────────────┐
# │        NumPy C Engine         │  ← REAL WORK HERE ⚡
# │   - loops in C                │
# │   - memory optimized          │
# │   - SIMD instructions         │
# └───────────────▲───────────────┘
#                 │ CPU executes machine code
#                 ▼
# ┌───────────────────────────────┐
# │            Hardware (CPU)     │
# └───────────────────────────────┘

# %% [markdown]
# 5) Memory Diagram (Important 🔥)
# Python List (slow)
# [ 1 ] → object
# [ 2 ] → object
# [ 3 ] → object
# [ 4 ] → object
#
#
# Each element is a separate object → slow.
